# %% [markdown]
# # 礼帽与黑帽

# %% [markdown]
# # 1. 礼帽（原图像和原图像开运算结果的差值）

# %% [markdown]
# ① 礼帽 = 原始输入-开运算（开运算可以理解为先腐蚀后扩张）

# %%
import cv2 #opencv的缩写为cv2
import matplotlib.pyplot as plt # matplotlib库用于绘图展示
import numpy as np   # numpy数值计算工具包

# 魔法指令，直接展示图，Jupyter notebook特有
# %matplotlib inline

# %%
# 礼帽 
# 原始带刺，开运算不带刺，原始输入-开运算 = 刺（开运算可以理解为先腐蚀后扩张）
img = cv2.imread('01_Picture/05_Dige.png')
kernel = np.ones((5,5),np.uint8) # 创建尺寸大小为5×5的核，uint8代表无符号整数（0 to 255）
tophat = cv2.morphologyEx(img,cv2.MORPH_TOPHAT,kernel)
cv2.imshow('tophat',tophat)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ps:numpy中**ones函数**用于创建数组，详解https://www.runoob.com/numpy/numpy-array-creation.html

# %% [markdown]
# 运行结果
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. 黑帽（我的理解：主要为了得到汉字边缘）

# %% [markdown]
# ② 黑帽 = 闭运算-原始输入（闭运算可以理解为先扩张后腐蚀）

# %%
# 黑帽  
# 原始带刺，闭运算带刺并且比原始边界胖一点，闭运算-原始输入 = 原始整体
img = img = cv2.imread('01_Picture/05_Dige.png')
kernel = np.ones((5,5),np.uint8)
blackhat = cv2.morphologyEx(img,cv2.MORPH_BLACKHAT,kernel)
cv2.imshow('blackhat',blackhat)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# 运行结果
# ![image.png](attachment:image.png)
