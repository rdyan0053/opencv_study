# %% [markdown]
# # 打开jupyter发现kernel不是自己设置的环境，而是python3

# %% [markdown]
# 自己使用conda创建了一个study环境，里面安装了opencv，但是在jupyter里面显示没有导入，错误原因是kernel没有切换

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 解决办法：https://blog.csdn.net/weixin_44918193/article/details/112913584
